# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
df = pd.read_csv(r"https://vincentarelbundock.github.io/Rdatasets/csv/Ecdat/Benefits.csv")
df.head()
# Out:
#    rownames  stateur  statemb  state  age  tenure     joblost nwhite school12  \
# 0         1      4.5      167     42   49      21       other     no       no
# 1         2     10.5      251     55   26       2  slack_work     no       no
# 2         3      7.2      260     21   40      19       other     no      yes
# 3         4      5.8      245     56   51      17  slack_work    yes       no
# 4         5      6.5      125     58   33       1  slack_work     no      yes
#
#       sex bluecol smsa married dkids dykids  yrdispl        rr head   ui
# 0    male     yes  yes      no    no     no        7  0.290631  yes  yes
# 1    male     yes  yes      no   yes    yes       10  0.520202  yes   no
# 2  female     yes  yes     yes    no     no       10  0.432490  yes  yes
# 3  female     yes  yes     yes    no     no       10  0.500000   no  yes
# 4    male     yes  yes     yes   yes    yes        4  0.390625  yes   no

# %%
df['stateur'].value_counts()
# Out:
# stateur
# 7.2     171
# 7.5     139
# 6.3     119
# 5.4     117
# 5.8     115
#        ...
# 14.7      4
# 10.9      3
# 2.4       3
# 2.2       2
# 2.6       2
# Name: count, Length: 109, dtype: int64

# %%
df['state'].unique()
# Out:
# array([42, 55, 21, 56, 58, 11, 93, 84, 33, 12, 22, 54, 16, 83, 44, 73, 43,
#        59, 62, 88, 74, 34, 61, 72, 86, 57, 71, 52, 14, 64, 41, 94, 82, 13,
#        15, 31, 51, 23, 46, 91, 81, 85, 92, 87, 45, 47, 63, 35, 32, 95, 53],
#       dtype=int64)

# %%
df.groupby(['state', 'joblost', 'school12', 'stateur']).agg({'statemb': 'mean'}).head(30)
# Out:
#                                            statemb
# state joblost            school12 stateur
# 11    other              no       3.8        161.0
#                                   4.1        171.0
#                                   4.4        152.0
#                                   5.1        180.0
#                                   5.3        146.0
#                                   5.4        139.0
#                                   7.5        188.0
#                                   9.0        124.0
#                          yes      4.1        171.0
#       position_abolished no       6.1        133.0
#                                   7.6        115.0
#                                   9.0        124.0
#                          yes      5.1        180.0
#       seasonal_job_ended no       3.8        161.0
#                                   9.0        124.0
#       slack_work         no       4.1        171.0
#                                   5.1        180.0
#                                   5.4        139.0
#                                   6.1        133.0
#                                   7.5        188.0
#                                   7.6        115.0
#                                   9.0        124.0
#                          yes      5.1        180.0
#                                   5.3        146.0
#                                   7.5        188.0
#                                   7.6        115.0
# 12    other              no       2.4        156.0
#                                   2.5        150.0
#                                   2.8        150.0
#                                   3.9        141.0
